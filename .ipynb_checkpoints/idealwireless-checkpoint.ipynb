# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
idealwireless = pd.read_csv('idealwireless.csv')

# %%
idealwireless.head()
# Out:
#                               run     type module name       attrname  \
# 0  Ping1-0-20210506-16:45:47-8914  runattr    NaN  NaN     configname
# 1  Ping1-0-20210506-16:45:47-8914  runattr    NaN  NaN       datetime
# 2  Ping1-0-20210506-16:45:47-8914  runattr    NaN  NaN     experiment
# 3  Ping1-0-20210506-16:45:47-8914  runattr    NaN  NaN        inifile
# 4  Ping1-0-20210506-16:45:47-8914  runattr    NaN  NaN  iterationvars
#
#            attrvalue  value  count  sumweights  mean  stddev  min  max  \
# 0              Ping1    NaN    NaN         NaN   NaN     NaN  NaN  NaN
# 1  20210506-16:45:47    NaN    NaN         NaN   NaN     NaN  NaN  NaN
# 2              Ping1    NaN    NaN         NaN   NaN     NaN  NaN  NaN
# 3        omnetpp.ini    NaN    NaN         NaN   NaN     NaN  NaN  NaN
# 4                NaN    NaN    NaN         NaN   NaN     NaN  NaN  NaN
#
#   binedges binvalues
# 0      NaN       NaN
# 1      NaN       NaN
# 2      NaN       NaN
# 3      NaN       NaN
# ...

# %%
tmp = idealwireless[(idealwireless.type=='scalar')]

# %%
tmp.head()
# Out:
# Empty DataFrame
# Columns: [run, type, module, name, attrname, attrvalue, value, count, sumweights, mean, stddev, min, max, binedges, binvalues]
# Index: []

# %%
idealwireless.module.unique()
# Out:
# array([nan, 'Net.radioMedium.propagation', 'Net.radioMedium',
#        'Net.host[0].lo[0].lo', 'Net.host[0].wlan[0].mac.queue',
#        'Net.host[0].wlan[0].mac', 'Net.host[0].wlan[0].radio',
#        'Net.host[0].ipv4.ip', 'Net.host[0].ipv4.arp', 'Net.host[0].udp',
#        'Net.host[1].lo[0].lo', 'Net.host[1].wlan[0].mac.queue',
#        'Net.host[1].wlan[0].mac', 'Net.host[1].wlan[0].radio',
#        'Net.host[1].ipv4.ip', 'Net.host[1].ipv4.arp', 'Net.host[1].udp',
#        'Net.host[1].app[0]', 'Net.host[1].app[1]', 'Net.host[2].lo[0].lo',
#        'Net.host[2].wlan[0].mac.queue', 'Net.host[2].wlan[0].mac',
#        'Net.host[2].wlan[0].radio', 'Net.host[2].ipv4.ip',
#        'Net.host[2].ipv4.arp', 'Net.host[2].udp', 'Net.host[2].app[0]',
#        'Net.host[2].app[1]', 'Net.host[3].lo[0].lo',
#        'Net.host[3].wlan[0].mac.queue', 'Net.host[3].wlan[0].mac',
#        'Net.host[3].wlan[0].radio', 'Net.host[3].ipv4.ip',
# ...
