# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
aloha = pd.read_csv('aloha.csv')

# %%
aloha.head()
# Out:
#                                              run     type module name  \
# 0  PureAlohaExperiment-0-20170627-20:42:16-22739  runattr    NaN  NaN
# 1  PureAlohaExperiment-0-20170627-20:42:16-22739  runattr    NaN  NaN
# 2  PureAlohaExperiment-0-20170627-20:42:16-22739  runattr    NaN  NaN
# 3  PureAlohaExperiment-0-20170627-20:42:16-22739  runattr    NaN  NaN
# 4  PureAlohaExperiment-0-20170627-20:42:16-22739  runattr    NaN  NaN
#
#         attrname              attrvalue  value  count  sumweights  mean  \
# 0     configname    PureAlohaExperiment    NaN    NaN         NaN   NaN
# 1       datetime      20170627-20:42:16    NaN    NaN         NaN   NaN
# 2     experiment    PureAlohaExperiment    NaN    NaN         NaN   NaN
# 3        inifile            omnetpp.ini    NaN    NaN         NaN   NaN
# 4  iterationvars  numHosts=10, iaMean=1    NaN    NaN         NaN   NaN
#
#    stddev  min  max binedges binvalues
# 0     NaN  NaN  NaN      NaN       NaN
# ...

# %%
aloha.tail()
# Out:
#                                                  run       type        module  \
# 2095  PureAlohaExperiment-41-20170627-20:42:22-22773  histogram  Aloha.server
# 2096  PureAlohaExperiment-41-20170627-20:42:22-22773       attr  Aloha.server
# 2097  PureAlohaExperiment-41-20170627-20:42:22-22773  histogram  Aloha.server
# 2098  PureAlohaExperiment-41-20170627-20:42:22-22773       attr  Aloha.server
# 2099  PureAlohaExperiment-41-20170627-20:42:22-22773       attr  Aloha.server
#
#                                  name attrname  \
# 2095        collisionLength:histogram      NaN
# 2096        collisionLength:histogram    title
# 2097  collisionMultiplicity:histogram      NaN
# 2098  collisionMultiplicity:histogram   source
# 2099  collisionMultiplicity:histogram    title
#
#                               attrvalue  value   count  sumweights      mean  \
# 2095                                NaN    NaN  1842.0         NaN  0.158076
# ...

# %%
aloha.iloc[1200:1205]
# Out:
#                                                 run    type        module  \
# 1200  PureAlohaExperiment-1-20170627-20:42:17-22739  scalar  Aloha.server
# 1201  PureAlohaExperiment-1-20170627-20:42:17-22739    attr  Aloha.server
# 1202  PureAlohaExperiment-1-20170627-20:42:17-22739    attr  Aloha.server
# 1203  PureAlohaExperiment-1-20170627-20:42:17-22739  scalar  Aloha.server
# 1204  PureAlohaExperiment-1-20170627-20:42:17-22739    attr  Aloha.server
#
#                          name           attrname              attrvalue  \
# 1200      collidedFrames:last                NaN                    NaN
# 1201      collidedFrames:last             source         sum(collision)
# 1202      collidedFrames:last              title  collided frames, last
# 1203  channelUtilization:last                NaN                    NaN
# 1204  channelUtilization:last  interpolationmode                 linear
#
#              value  count  sumweights  mean  stddev  min  max binedges  \
# ...
