# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
multicast = pd.read_csv('multicast.csv')

# %%
multicast.head()
# Out:
#                                 run     type module name       attrname  \
# 0  General-0-20210506-16:15:18-7390  runattr    NaN  NaN     configname
# 1  General-0-20210506-16:15:18-7390  runattr    NaN  NaN       datetime
# 2  General-0-20210506-16:15:18-7390  runattr    NaN  NaN     experiment
# 3  General-0-20210506-16:15:18-7390  runattr    NaN  NaN        inifile
# 4  General-0-20210506-16:15:18-7390  runattr    NaN  NaN  iterationvars
#
#            attrvalue  value  count  sumweights  mean  stddev  min  max  \
# 0            General    NaN    NaN         NaN   NaN     NaN  NaN  NaN
# 1  20210506-16:15:18    NaN    NaN         NaN   NaN     NaN  NaN  NaN
# 2            General    NaN    NaN         NaN   NaN     NaN  NaN  NaN
# 3        omnetpp.ini    NaN    NaN         NaN   NaN     NaN  NaN  NaN
# 4                NaN    NaN    NaN         NaN   NaN     NaN  NaN  NaN
#
#   binedges binvalues
# 0      NaN       NaN
# 1      NaN       NaN
# 2      NaN       NaN
# ...

# %%
tmp = multicast[(multicast.type=='scalar') & (multicast.module=='MulticastNetwork.host1.ipv4')]

# %%
tmp.head()
# Out:
# Empty DataFrame
# Columns: [run, type, module, name, attrname, attrvalue, value, count, sumweights, mean, stddev, min, max, binedges, binvalues]
# Index: []

# %%
tmp.iloc[50:100]
# Out:
# Empty DataFrame
# Columns: [run, type, module, name, attrname, attrvalue, value, count, sumweights, mean, stddev, min, max, binedges, binvalues]
# Index: []
